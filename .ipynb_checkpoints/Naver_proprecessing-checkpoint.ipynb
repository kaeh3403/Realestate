# %%
import pandas as pd

# %%
list_data = pd.read_csv('./data/meamul_up_to_date_list.csv')
detail_data = pd.read_csv('./data/meamul_up_to_date_detail.csv')
landbook = pd.read_csv('./data/landbook.csv')

# %%
del list_data['longitude'], list_data['latitude']
del landbook['naver_pnu']

# %%
all_data = pd.merge(list_data, detail_data, left_on='articleNo',right_on='articleNo',how='outer')

# %%
all_data.rename(columns = {'longitude' : 'naver_longitude'}, inplace=True)
all_data.rename(columns = {'latitude' : 'naver_latitude'},inplace=True)

# %%
a = pd.merge(all_data, landbook, on = ['naver_longitude','naver_latitude'],how='outer')

# %%
a.drop_duplicates()
# Out:
#        articleNo articleName_x articleStatus realEstateTypeCode  \
# 0     2203341748        중소형사무실            R0                SMS
# 2     2203318257        지식산업센터            R0             APTHGJ
# 4     2203332682            공장            R0               GJCG
# 6     2203700535        지식산업센터            R0             APTHGJ
# 8     2202795669            공장            R0               GJCG
# ...          ...           ...           ...                ...
# 1753  2204799872        중소형사무실            R0                SMS
# 1754  2204732873         대형사무실            R0                SMS
# 1755  2204732905         대형사무실            R0                SMS
# 1756  2204790104            빌딩            R0                 GM
# 1757  2204788738          상가건물            R0                 GM
#
#      realEstateTypeName articleRealEstateTypeCode articleRealEstateTypeName  \
# 0                   사무실                       D01                       사무실
# 2                지식산업센터                       E02                    지식산업센터
# 4                 공장/창고                       E02                     공장/창고
# 6                지식산업센터                       E02                    지식산업센터
# 8                 공장/창고                       E02                     공장/창고
# ...                 ...                       ...                       ...
# 1753                사무실                       D01                       사무실
# 1754                사무실                       D01                       사무실
# 1755                사무실                       D01                       사무실
# 1756                 건물                       D03                     빌딩/건물
# 1757                 건물                       D03                      상가건물
#
#      tradeTypeCode_x tradeTypeName_x verificationTypeCode_x  ...     area  \
# 0                 B2              월세                   SITE  ...  15788.0
# 2                 B2              월세                   SITE  ...  15788.0
# 4                 B2              월세                   SITE  ...  15788.0
# 6                 B2              월세                  OWNER  ...  15788.0
# 8                 B2              월세                   SITE  ...  15788.0
# ...              ...             ...                    ...  ...      ...
# 1753              B2              월세                    DOC  ...      NaN
# 1754              B2              월세                    DOC  ...      NaN
# 1755              B2              월세                    DOC  ...      NaN
# 1756              A1              매매                    DOC  ...      NaN
# 1757              A1              매매                   NONE  ...      NaN
#
#      connection_area landuse_zone  landuse_district jimok  lot_road  \
# 0            15788.0       일반공업지역            철도보호지구    공장      광대소각
# 2            15788.0       일반공업지역            철도보호지구    공장      광대소각
# 4            15788.0       일반공업지역            철도보호지구    공장      광대소각
# 6            15788.0       일반공업지역            철도보호지구    공장      광대소각
# 8            15788.0       일반공업지역            철도보호지구    공장      광대소각
# ...              ...          ...               ...   ...       ...
# 1753             NaN          NaN               NaN   NaN       NaN
# 1754             NaN          NaN               NaN   NaN       NaN
# 1755             NaN          NaN               NaN   NaN       NaN
# 1756             NaN          NaN               NaN   NaN       NaN
# 1757             NaN          NaN               NaN   NaN       NaN
#
#       lot_height lot_shape  icp_potential_landlocked development_state
# 0             평지       가장형                     False               NaN
# 2             평지       가장형                     False               NaN
# 4             평지       가장형                     False               NaN
# 6             평지       가장형                     False               NaN
# 8             평지       가장형                     False               NaN
# ...          ...       ...                       ...               ...
# 1753         NaN       NaN                       NaN               NaN
# 1754         NaN       NaN                       NaN               NaN
# 1755         NaN       NaN                       NaN               NaN
# 1756         NaN       NaN                       NaN               NaN
# 1757         NaN       NaN                       NaN               NaN
#
# [1532 rows x 145 columns]

# %%
a.drop_duplicates().to_csv('a1.csv', index = False, encoding = "utf-8-sig")

# %%
0%99
# Out:
# 0
