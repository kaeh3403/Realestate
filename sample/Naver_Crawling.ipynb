# %%
import pandas as pd
import os
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains

# %%
# !conda install selenium
# Out:
# ^C

# %%
driver = webdriver.Chrome('./chromedriver_win')

# %%
driver.get('https://new.land.naver.com/offices?ms=37.506817,126.721713,15&a=SMS:GJCG:APTHGJ:GM:TJ&e=RETAIL')

# %%
https://new.land.naver.com/offices?ms=37.5191143,126.7158818,19&a=SMS:GJCG:APTHGJ:GM:TJ&e=RETAIL&articleNo=2202529729

# %%
https://new.land.naver.com/api/articles/2202529729?complexNo=

# %%
driver.
# Out:
# 'dd257aab9964f6286344644cfa69db28'

# %%
a = driver.find_elements(By.XPATH, '//*[@id="listContents1"]/div/div/div/div')

# %%
for i in range(0,len(a)):
    a[i].click()
    b = a[0].find_elements(By.XPATH,'//*[@id="ct"]/div[2]/div[2]/div/div[2]')[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/hn/4ftm09pn31591gc29smn543r0000gn/T/ipykernel_60535/1811133769.py in <module>
#       1 for i in range(0,len(a)):
#       2     a[i].click()
# ----> 3     b = a[0].find_elements(By.XPATH,'//*[@id="ct"]/div[2]/div[2]/div/div[2]')[0]
#
# IndexError: list index out of range

# %%
a[1].click()

# %%
b = a[0].find_elements(By.XPATH,'//*[@id="ct"]/div[2]/div[2]/div/div[2]')[0]

# %%
info = b.find_element(By.CLASS_NAME,'main_info_area').text

# %%
detail = b.find_element(By.CLASS_NAME,'detail_box--summary').text

# %%
agent = b.find_element(By.CLASS_NAME, 'table_td_agent').text

# %%
element_to_hover_over = a[1].find_element(By.CLASS_NAME, "item_inner")

# %%
element_to_hover_over = a[1].find_element(By.CLASS_NAME, "item_inner")
hover = ActionChains(driver).move_to_element(element_to_hover_over)
hover.perform()

# %%
hover.text
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11804/1211014758.py in <module>
# ----> 1 hover.text
#
# AttributeError: 'ActionChains' object has no attribute 'text'

# %%
a[11].screenshot_as_png('test.png')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/hn/4ftm09pn31591gc29smn543r0000gn/T/ipykernel_60535/1233976559.py in <module>
# ----> 1 a[11].screenshot_as_png('test.png')
#
# TypeError: 'bytes' object is not callable

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11804/4284490767.py in <module>
#       3
#       4 # Access requests via the `requests` attribute
# ----> 5 for request in driver.requests:
#       6     if request.response:
#       7         print(
#
# AttributeError: 'WebDriver' object has no attribute 'requests'

# %%
a.click()

# %%
from selenium import webdriver  # Import from seleniumwire

# Create a new instance of the Firefox driver
driver = webdriver.Firefox()

# Go to the Google home page
driver.get('https://www.google.com')

# Access requests via the `requests` attribute
for request in driver.requests:
    if request.response:
        print(
            request.url,
            request.response.status_code,
            request.response.headers['Content-Type']
        )
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11804/3750090093.py in <module>
#       8
#       9 # Access requests via the `requests` attribute
# ---> 10 for request in driver.requests:
#      11     if request.response:
#      12         print(
#
# AttributeError: 'WebDriver' object has no attribute 'requests'

# %%
driver = webdriver.Firefox()

# %%
driver.get('https://new.land.naver.com/offices?ms=37.506817,126.721713,15&a=SMS:GJCG:APTHGJ:GM:TJ&e=RETAIL')

# %%
driver.page_source
# Out:
# '<html class="no-js" data-user-agent="Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:96.0) Gecko/20100101 Firefox/96.0" lang="ko"><head><meta charset="utf-8"><meta http-equiv="X-UA-Compatible" content="IE=edge"><title>네이버 부동산</title><meta name="description" content="네이버 부동산"><meta property="og:type" content="article"><meta property="og:article:author" content="네이버 부동산"><meta property="og:article:author:url" content="http://m.land.naver.com"><meta property="og:title" content="네이버 부동산"><meta property="og:url" content="http://m.land.naver.com"><meta property="og:image" content="https://landthumb-phinf.pstatic.net/20201030_229/land_naver_1604037626049TB83t_PNG/%B3%D7%C0%CC%B9%F6_%BA%CE%B5%BF%BB%EA.png"><meta property="og:description" content="네이버 부동산"><meta name="description" content="네이버 부동산"><meta name="referrer" content="always"><link rel="icon" href="https://m.naver.com/favicon.ico" type="image/x-icon"><link rel="shortcut icon" href="https://m.naver.com/favicon.ico" type="image/x-icon"
# ...

# %%
parsed_json = json.loads(driver.page_source)
print(parsed_json)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11804/469269365.py in <module>
# ----> 1 parsed_json = json.loads(driver.page_source)
#       2 print(parsed_json)
#
# ~\anaconda3\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     344             parse_int is None and parse_float is None and
#     345             parse_constant is None and object_pairs_hook is None and not kw):
# --> 346         return _default_decoder.decode(s)
#     347     if cls is None:
#     348         cls = JSONDecoder
#
# ~\anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ...

# %%
import json

# %%
driver.capabilities.popitem()
# Out:
# ('unhandledPromptBehavior', 'dismiss and notify')
